# %%
import logging

from ppcluster.config import ConfigManager
from sqlalchemy import create_engine

logger = logging.getLogger("ppcx")

config = ConfigManager()
db_engine = create_engine(config.db_url)


cvat_host = "150.145.51.193"
cvat_port = "8081"
cvat_user = "francescoioli"
cvat_password = "vkq0hex_qah@TZA4hbm"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import logging
# ----> 3 from ppcluster.config import ConfigManager
#       4 from sqlalchemy import create_engine
#       6 logger = logging.getLogger("ppcx")
#
# ModuleNotFoundError: No module named 'ppcluster.config'
